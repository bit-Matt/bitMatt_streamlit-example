# %%
import pandas as pd

# %%
df_provinces = pd.read_excel('../data/spreadsheets/average_total_amount_by_province.xlsx')

# %%
df_provinces
# Out:
#                           PROVINCE  TOTAL_AMOUNT_SUM
# 0               OCCIDENTAL MINDORO     742140.106038
# 1                          PALAWAN     602063.396960
# 2                           BATAAN     584687.634360
# 3                  SURIGAO DEL SUR     524928.444503
# 4                  DAVAO DEL NORTE     452229.154193
# 5                      NUEVA ECIJA     438968.631973
# 6        COTABATO (NORTH COTABATO)     437115.776739
# 7            SAMAR (WESTERN SAMAR)     425893.095393
# 8                          ISABELA     416356.243281
# 9                 MISAMIS ORIENTAL     412741.405914
# 10             ZAMBOANGA DEL NORTE     409693.453645
# 11                        BUKIDNON     406897.875516
# 12                AGUSAN DEL NORTE     399447.185789
# 13                         BENGUET     399228.672824
# 14                  NORTHERN SAMAR     395078.571596
# 15                   CAMARINES SUR     388062.612581
# 16              MISAMIS OCCIDENTAL     385299.739078
# ...
