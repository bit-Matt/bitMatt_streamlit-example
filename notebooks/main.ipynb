# %%
import pandas as pd

# %%
df_provinces = pd.read_excel('../data/spreadsheets/average_total_amount_by_provinces.xlsx')

# %%
df_provinces
# Out:
#                           PROVINCE  AVERAGE_AMOUNT_Credit  \
# 0                 AGUSAN DEL NORTE            2129.755514
# 1                   AGUSAN DEL SUR            2730.848385
# 2                            AKLAN            3982.156489
# 3                            ALBAY            2017.930669
# 4                          ANTIQUE            2547.532050
# 5                           BATAAN            3368.289607
# 6                          BENGUET            2194.532004
# 7                            BOHOL            2645.539342
# 8                         BUKIDNON            2474.153086
# 9                          CAGAYAN            4534.079808
# 10                 CAMARINES NORTE            3256.662279
# 11                   CAMARINES SUR            2060.667360
# 12                           CAPIZ            2686.391946
# 13       COTABATO (NORTH COTABATO)            3205.709582
# 14  COTABATO CITY (NOT A PROVINCE)            2384.085895
# ...
