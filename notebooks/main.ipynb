# %%
import pandas as pd

customer_df = pd.read_excel('../data/spreadsheets/CUSTOMER INFO_PJDSC.xlsx')

customer_df
# Out:
#             CUST_NUM            PROVINCE  \
# 0       11712.654012             BENGUET
# 1         436.605085             BENGUET
# 2         921.989154             BENGUET
# 3        1119.634762             BENGUET
# 4        1709.755538             BENGUET
# ...              ...                 ...
# 138439  14060.827927      SULTAN KUDARAT
# 138440  14101.987945      SULTAN KUDARAT
# 138441  11266.634103  OCCIDENTAL MINDORO
# 138442   8992.043372  OCCIDENTAL MINDORO
# 138443  11776.173572  OCCIDENTAL MINDORO
#
#                                         REGION EDUCATION   AGE    TENURE  \
# 0       CORDILLERA ADMINISTRATIVE REGION (CAR)   NO_DATA  20.0  1.833333
# 1       CORDILLERA ADMINISTRATIVE REGION (CAR)   NO_DATA  21.0  4.250000
# 2       CORDILLERA ADMINISTRATIVE REGION (CAR)   NO_DATA  23.0  2.000000
# 3       CORDILLERA ADMINISTRATIVE REGION (CAR)       LOW  13.0  5.583333
# 4       CORDILLERA ADMINISTRATIVE REGION (CAR)   NO_DATA  20.0  1.250000
# ...

# %%
# get the unique regions

customer_df['REGION'].unique()
# Out:
# array(['CORDILLERA ADMINISTRATIVE REGION (CAR)',
#        'REGION V (BICOL REGION)', 'REGION XII (SOCCSKSARGEN)',
#        'REGION I (ILOCOS REGION)', 'REGION III (CENTRAL LUZON)',
#        'REGION VII (CENTRAL VISAYAS)', 'REGION X (NORTHERN MINDANAO)',
#        'REGION IX (ZAMBOANGA PENINSULA)', 'REGION VI (WESTERN VISAYAS)',
#        'REGION VIII (EASTERN VISAYAS)', 'REGION XIII (CARAGA)',
#        'MIMAROPA REGION', 'REGION XI (DAVAO REGION)',
#        'REGION II (CAGAYAN VALLEY)'], dtype=object)
