# %%
import pandas as pd

merged_df = pd.read_excel('../data/spreadsheets/average_total_amount_by_region.xlsx')

# %%
merged_df
# Out:
#                                     REGION  TOTAL_AMOUNT_SUM
# 0                          MIMAROPA REGION     532428.751749
# 1                 REGION XI (DAVAO REGION)     430793.289113
# 2               REGION III (CENTRAL LUZON)     429009.717550
# 3             REGION X (NORTHERN MINDANAO)     402540.910280
# 4   CORDILLERA ADMINISTRATIVE REGION (CAR)     399228.672824
# 5               REGION II (CAGAYAN VALLEY)     397246.680172
# 6                     REGION XIII (CARAGA)     382418.467290
# 7                REGION XII (SOCCSKSARGEN)     372698.065594
# 8            REGION VIII (EASTERN VISAYAS)     362592.715758
# 9                  REGION V (BICOL REGION)     357628.994910
# 10                REGION I (ILOCOS REGION)     355771.098429
# 11            REGION VII (CENTRAL VISAYAS)     349618.406652
# 12         REGION IX (ZAMBOANGA PENINSULA)     348224.933532
# 13             REGION VI (WESTERN VISAYAS)     336891.144115

# %%
merged_df[['REGION', 'AVERAGE_AMOUNT_Credit']]
# Out:
#                                     REGION  AVERAGE_AMOUNT_Credit
# 0               REGION III (CENTRAL LUZON)            8470.925851
# 1                     REGION XIII (CARAGA)            8159.039619
# 2                 REGION I (ILOCOS REGION)            7971.156987
# 3               REGION II (CAGAYAN VALLEY)            7935.049840
# 4                          MIMAROPA REGION            7851.263737
# 5          REGION IX (ZAMBOANGA PENINSULA)            7646.822475
# 6                 REGION XI (DAVAO REGION)            7517.073205
# 7            REGION VIII (EASTERN VISAYAS)            7468.342945
# 8                REGION XII (SOCCSKSARGEN)            7340.373327
# 9                  REGION V (BICOL REGION)            6951.928791
# 10  CORDILLERA ADMINISTRATIVE REGION (CAR)            6643.129964
# 11            REGION X (NORTHERN MINDANAO)            6444.246611
# 12             REGION VI (WESTERN VISAYAS)            6145.602252
# ...
